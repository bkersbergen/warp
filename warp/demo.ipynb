# %%
import matplotlib.pyplot as plt
import warp
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
new_sin = warp.expand_extract(np.sin, period=(np.pi*2), factor=.3)
# Out:
# 3.141592653589793
# 3.142306939304079

# %%
x = np.linspace(0, 2*np.pi, 1000)

# %%
plt.plot(x, new_sin(x));

# %%
np.vectorize(new_sin)(4)
# Out:
# array(-0.4783154618845682)

# %%
np.sin(4)
# Out:
# -0.7568024953079282

# %%
long_sin = warp.compress(np.sin)

# %%
plt.plot(x, long_sin(x))

# %%
plt.plot(x, np.sin(x))
